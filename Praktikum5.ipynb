# %% [markdown]
# <a href="https://colab.research.google.com/github/galihsuryahadi/ddp-25/blob/main/Praktikum5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namakendaraan = "vario"
jeniskendaraan = "motor"
cckendaraan = 150
warnakendaraan = "merah"
rodakendaraan = 2

data_kendaraan =[
namakendaraan, jeniskendaraan, cckendaraan, warnakendaraan, rodakendaraan]
print(data_kendaraan)

hargakendaraan = 5000
tipekendaraan = "matic"

data_kendaraan.append(hargakendaraan)
data_kendaraan.append(tipekendaraan)
print(data_kendaraan)

merkkendaraan = "honda"
data_kendaraan.insert(2,merkkendaraan)
print(data_kendaraan)
# Out:
# ['vario', 'motor', 150, 'merah', 2]
# ['vario', 'motor', 150, 'merah', 2, 5000, 'matic']
# ['vario', 'motor', 'honda', 150, 'merah', 2, 5000, 'matic']

# %%
pilihan = int(input("""
silahkan pilih menu yang diinginkan
====================================
1. Luas persegi
2. Luas lingkaran
3. Luas segitiga
====================================
Kirimkan hanya angka saja,
jawaban = """))

match pilihan:
  case 1:
    sisi = int(input("sisi = "))
    luas = sisi * sisi
    print(f"luas persegi dengan sisi {sisi} adalah {luas}")
  # luas persegi
  case 2:
  # luas lingkaran
  # phi * jari-jari**2
    print(f"luas lingkaran")
  case 3:
  # luas segitiga
  # (alas * tinggi)/2
    print("")
  case _:
    print("ya ndak tau kok tanya saya si")
# Out:
# silahkan pilih menu yang diinginkan
# ====================================
# 1. Luas persegi
# 2. Luas lingkaran
# 3. Luas segitiga
# ====================================
# Kirimkan hanya angka saja,
# jawaban = 1
# sisi = 1
# luas persegi dengan sisi 1 adalah 1
